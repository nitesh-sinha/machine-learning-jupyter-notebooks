# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix, andrews_curves
from numpy.random import randn, randint, uniform, sample

# %% [markdown]
# ## 1. matplotlib pyplot

# %%
df = pd.DataFrame(randn(1000), index=pd.date_range('2019-06-07', periods=1000), columns=['value'])
ts = pd.Series(randn(1000), index=pd.date_range('2019-06-07', periods=1000))

# %%
ts
# Out:
# 2019-06-07   -0.580379
# 2019-06-08   -0.644479
# 2019-06-09   -2.398278
# 2019-06-10   -0.269142
# 2019-06-11   -0.141980
#                 ...
# 2022-02-26   -0.835951
# 2022-02-27   -1.019806
# 2022-02-28    0.906640
# 2022-03-01   -1.119684
# 2022-03-02    1.077148
# Freq: D, Length: 1000, dtype: float64

# %%
df
# Out:
#                value
# 2019-06-07  1.454902
# 2019-06-08 -1.710625
# 2019-06-09 -0.444270
# 2019-06-10 -0.110312
# 2019-06-11 -2.120887
# ...              ...
# 2022-02-26  0.688805
# 2022-02-27  1.255987
# 2022-02-28  1.349497
# 2022-03-01  0.465197
# 2022-03-02 -0.717476
#
# [1000 rows x 1 columns]

# %%
ts.plot(figsize=(10,5)) # Internally it calls matplotlib(by default unless changed) to plot graphs

# %%
df.plot(grid=True, figsize=(10,5), kind='hist', bins=100)

# %%
cum_ts = ts.cumsum() # cumulative sum
cum_ts.plot(figsize=(10,5))

# %%
cum_ts.plot(figsize=(10,5), x_compat=True) # suppresses the x-ticks labels

# %%
plt.plot(cum_ts) # matplotlib function to plot the data

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_plot = iris.plot(figsize=(10,5), title='Iris dataset')
iris_plot.set_xlabel('index values')
iris_plot.set_ylabel('flower length/width')
# Out:
# Text(0, 0.5, 'flower length/width')

# %%
iris.plot(subplots=True) # plot each numeric column in its own subplot
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a3cf7fd10>,
# ...
#       dtype=object)

# %%
# plot subplots in 2*3 grid fashion
iris.plot(subplots=True, layout=(2,3), figsize=(20,10), sharex=False) # x-axis of each subplot is not shared
plt.tight_layout()

# %%
iris.plot(figsize=(10,5), logy=True, grid=True)

# %%
iris_updated = iris.drop('species',axis=1)

# %%
iris_plt = iris_updated.iloc[0].plot(kind='bar')
iris_plt.get_children() # To check which index has the rectangles(so we can color them differently next)
# Out:
# ...
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
# ...

# %%
iris_plt = iris_updated.iloc[0].plot(kind='bar')
# Will change the bar colors
iris_plt.get_children()[0].set_color('black')
iris_plt.get_children()[1].set_color('b') # b = blue(see color definitions at: https://matplotlib.org/2.1.1/api/_as_gen/matplotlib.pyplot.plot.html)
iris_plt.get_children()[2].set_color('grey')
iris_plt.get_children()[3].set_color('orange')
iris_plt

# %%
iris_updated.iloc[0].plot.bar()

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic['pclass'].plot.bar()

# %%
titanic['fare'].plot(figsize=(10,5))

# %%
titanic['fare'].diff().plot(figsize=(10,5))

# %%
titanic['survived'].plot(kind='hist', title='Survived titanic wreck', bins=20)

# %%
df = pd.DataFrame(randn(10,4), columns=['a','b','c','d'])
df.plot(grid=True, kind='box')

# %%
df['d'].describe() # Min point in d column is excluded from the bar in the bar plot above
# Out:
# count    10.000000
# mean     -0.018201
# std       1.080824
# min      -2.107032
# 25%      -0.361219
# 50%      -0.005170
# 75%       0.642686
# max       1.423953
# Name: d, dtype: float64

# %%
df['c'].plot(kind='hist')

# %%
df.plot.hist() # Plots histogram of all columns on same figure

# %%
df.hist() # Plots histogram of each column is a separate subplot
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2f914ad0>,
# ...
#       dtype=object)

# %%
pd.Series(randn(100)).plot.bar()

# %%
iris.plot(kind='hist', bins=50) # Keep larger number of bins to see fine grained distribution of data across samples

# %%
iris.plot(kind='hist', bins=50, orientation='horizontal', stacked='True')

# %%
df.loc[0,'a'] = np.NaN
df.loc[5,'a'] = np.NaN
df.loc[7,'a'] = np.NaN
df.loc[9,'a'] = np.NaN

# %%
df
# Out:
#           a         b         c         d
# 0       NaN  0.409658 -1.533608  0.729794
# 1  0.487198  0.548242 -0.875573  1.271816
# 2  0.927951  1.417083  1.174114  0.381362
# 3  0.032170  0.650175 -0.717489  0.242352
# 4 -0.613502  0.600203 -0.248643  1.423953
# 5       NaN -0.531999 -1.283577 -1.178956
# 6 -0.557428 -1.431450  1.587120 -0.316478
# 7       NaN  1.261872  0.023085 -0.252692
# 8 -2.060026  1.289861 -0.438230 -2.107032
# 9       NaN -0.464720 -0.727149 -0.376133

# %%
df['a'].plot(kind='hist', bins=100)

# %%
x
# Out:
# 0    1
# 1   -2
# 2    3
# 3   -4
# 4   -5
# dtype: int64

# %%
x.diff()
# Out:
# 0    NaN
# 1   -3.0
# 2    5.0
# 3   -7.0
# 4   -1.0
# dtype: float64

# %%
iris['sepal_width'].diff().plot(kind = 'hist',bins = 50)

# %%
# alpha denotes the transparency of color(lower alpha is more transparent)
iris_updated.diff().hist(color='orange', figsize=(10,10), alpha=0.5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a2ae0ef10>,
# ...
#       dtype=object)

# %%
iris.plot(kind='scatter', x='sepal_length', y='petal_length')

# %%
iris.plot(kind='scatter', x='sepal_length', y='petal_length', c='sepal_width', s=100) # s=size, c=color

# %%
# Almost same as scatter plot
iris.plot.hexbin(x='sepal_length', y='petal_length', C='sepal_width', gridsize=20)

# %%
d = iris_updated.iloc[2]
d
# Out:
# sepal_length    4.7
# sepal_width     3.2
# petal_length    1.3
# petal_width     0.2
# Name: 2, dtype: float64

# %%
d.plot.pie(figsize=(10,10))

# %%
df = iris_updated.loc[0:3,:].T
df
# Out:
#                 0    1    2    3
# sepal_length  5.1  4.9  4.7  4.6
# sepal_width   3.5  3.0  3.2  3.1
# petal_length  1.4  1.4  1.3  1.5
# petal_width   0.2  0.2  0.2  0.2

# %%
df.plot.pie(subplots=True, figsize=(30,30), fontsize=20, autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a39cfbd10>,
# ...
#       dtype=object)

# %%
df.plot(kind='pie', subplots=True, figsize=(20,20),autopct='%.3f', fontsize=20)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a39fd1ed0>,
# ...
#       dtype=object)

# %%
# By default diagonal has the histogram plot
scatter_matrix(iris_updated, figsize=(10,10), color='black', diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a37f5e890>,
# ...
#       dtype=object)

# %%
iris['petal_length'].plot.kde()

# %%
andrews_curves(iris_updated, 'sepal_width')

# %%
ts.plot(style="r--") # Use red color dashes

# %%
# Combine two df line plots into one plot
x = iris_updated.drop(['sepal_length', 'petal_length'], axis=1)
y = iris_updated.drop(['petal_width', 'sepal_width'], axis=1)

# %%
# These two lines need to be together for the plot to be visible
x_plot = x.plot()
y.plot(figsize=(20,10), secondary_y=True, ax=x_plot) # For the *-length graphs use the scale on right side of plot below

# %%
# plot map data
from descartes import PolygonPatch
import geopandas as gpd
map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
map_df
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: London_Borough_Excluding_MHW.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-242-6e276a92778a> in <module>
#       2 from descartes import PolygonPatch
#       3 import geopandas as gpd
# ----> 4 map_df = gpd.read_file("London_Borough_Excluding_MHW.shp")
#       5 map_df
#
# /opt/anaconda3/lib/python3.7/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
# ...

# %% [markdown]
# ## 2. Seaborn

# %%
sns.set(style='darkgrid')

# %%
# Sample datasets to load at: https://github.com/mwaskom/seaborn-data
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='tip', style='day', data=tips, hue='smoker', size='size')

# %%
sns.relplot(data=tips, x='total_bill', y='tip')

# %%
# Looks same as default relplot
sns.scatterplot(data=tips, x='total_bill', y='tip')

# %%
sns.relplot(data=tips, x='tip', y='total_bill', style='size')

# %%
sns.relplot(data=tips, x='tip', y='total_bill', hue='size', col='time')

# %%
sns.relplot(data=tips, x='tip', y='total_bill', hue='smoker', col='size', col_wrap=3, height=4) # height of each subplot

# %%
df = pd.DataFrame(dict(time=np.arange(500), value=randn(500)))
df.head()
# Out:
#    time     value
# 0     0  0.489925
# 1     1  0.764398
# 2     2 -0.788057
# 3     3 -0.532197
# 4     4 -0.512815

# %%
sns.relplot(x='time', y='value', data=df, kind='line')

# %%
rand_df = pd.DataFrame(randn(500,2).cumsum(axis=1), columns=['value1', 'value2'])
rand_df
# Out:
#        value1    value2
# 0   -0.802093 -1.891416
# 1    1.183546  0.224340
# 2    0.165725 -1.160551
# 3   -2.164539  0.869986
# 4   -1.233107 -0.694021
# ..        ...       ...
# 495 -0.468622 -0.716607
# 496  1.251250  1.704941
# 497  0.621784  2.152049
# 498  1.282508  2.695920
# 499 -0.231643 -0.182079
#
# [500 rows x 2 columns]

# %%
sns.relplot(data=rand_df, x='value1', y='value2', kind='line')

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
# For the same timestamp(example 18) we have 56 datapoints
fmri[fmri['timepoint']==18]
# Out:
#     subject  timepoint event    region    signal
# 0       s13         18  stim  parietal -0.017552
# 2       s12         18  stim  parietal -0.081033
# 3       s11         18  stim  parietal -0.046134
# 4       s10         18  stim  parietal -0.037970
# 5        s9         18  stim  parietal -0.103513
# 6        s8         18  stim  parietal -0.064408
# 7        s7         18  stim  parietal -0.060526
# 8        s6         18  stim  parietal -0.007029
# 9        s5         18  stim  parietal -0.040557
# 10       s4         18  stim  parietal -0.048812
# 11       s3         18  stim  parietal -0.047148
# 12       s2         18  stim  parietal -0.086623
# 13       s1         18  stim  parietal -0.046659
# 14       s0         18  stim  parietal -0.075570
# 502      s2         18  stim   frontal -0.058471
# 515      s0         18  stim   frontal -0.048430
# 516      s1         18  stim   frontal -0.035852
# 518      s3         18  stim   frontal -0.010920
# ...

# %%
# If we plot this dataset with multiple y-axis datapoints for same point on x-axis,
# seaborn will, by default, aggregate the data and plot a line with mean(dark blue line) and 95% confidence
# interval around the mean(shown by blue shadow region)
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line')

# %%
# This is same plot as above but with confidence interval of 50% around the mean
# ci = 'sd' will mean ci of 1 standard deviation around the mean
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', ci=50)

# %%
# Turn off aggregation altogether use estimator=None
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', estimator=None)

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', hue='region', style='event', ci=50)

# %%
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', hue='region', style='event', markers=True, dashes=True)

# %%
# err_style denotes confidence interval drawn as bars or band(default)
sns.relplot(data=fmri, x='timepoint', y='signal', kind='line', hue='region', style='event', markers=True, ci=60, err_style='bars')

# %% [markdown]
# ### 2.1 - Categorical(non-numeric) data plotting

# %%
sns.catplot(data=tips, x='day', y='total_bill')

# %%
# Infact relplot on categorical data also gives similar output(except for same colour used for all points)
sns.catplot(data=tips, x='day', y='total_bill', jitter=False)

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='swarm', hue='size')

# %%
sns.catplot(data=tips, x='day', y='total_bill', kind='swarm', hue='size', order=['Sun', 'Sat', 'Thur', 'Fri'])

# %%
sns.catplot(data=tips, x='day', y='tip', kind='box', hue='sex')

# %%
sns.catplot(data=tips, x='day', y='tip', kind='box', hue='sex', dodge=False)

# %%
sns.catplot(data=tips, x='day', y='tip', kind='violin', hue='sex')

# %%
# Since violin shape is symmetric along the centre, its better to 
# split it to show hue on other side
sns.catplot(data=tips, x='day', y='tip', kind='violin', hue='sex', split=True)

# %%
# Combine two different types of plots into one
vio_plot = sns.catplot(data=tips, x='day', y='tip', kind='violin', inner=None)
sns.swarmplot(data=tips, x='day', y='tip',color='black', ax=vio_plot.ax)

# %%
diamonds = sns.load_dataset('diamonds')
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(x='color', y='price', kind='box', data=diamonds)

# %%
sns.catplot(x='color', y='price', kind='boxen', data=diamonds.sort_values('color'))

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(data=titanic, x='deck', kind='count', hue='pclass', palette='ch:0.25')

# %% [markdown]
# #### 2.2 - Visualizing Distribution of the Data(using seaborn)

# %%
# Draws a normalized histogram of probability density function of input data
# rug=False denotes no rug plot(A rug plot is a dataplot for single quantitaive variable.
# Think of a rug plot as a 1-D SCATTER PLOT)
sns.distplot(randn(1000), kde=True, hist=True, rug=False, bins=50)

# %%
# joint plot(similar to 2-D scatter plot)
sns.jointplot(data=tips, x='total_bill', y='tip')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='hex')

# %%
sns.jointplot(data=tips, x='total_bill', y='tip', kind='kde')

# %%
color_map = sns.cubehelix_palette(as_cmap = True, dark = 0, light = 1, reverse= True)
sns.kdeplot(tips['total_bill'], tips['tip'], cmap=color_map, shade=True, n_levels=50) # n_levels number of contours lines

# %%
# combine two types of plot
tips_kde_plot = sns.jointplot(data=tips, x='total_bill', y='tip', kind='kde', color='orange')
tips_kde_plot.plot_joint(plt.scatter, marker='+', c='red', s=40)
tips_kde_plot.ax_joint.collections[0].set_alpha(0) ## Not sure what this line does. No visible change in plot without it

# %%
# Pairplot is same as scatter matrix plot(in matplotlib)
sns.pairplot(iris)

# %%
g = sns.PairGrid(iris) # just draws 4*4 grid of axes lines(no plot on it yet)
g.map_diag(sns.kdeplot) # along the main diagonal KDE plot is drawn
g.map_offdiag(sns.kdeplot) # KDE plot along off diagonals also drawn now

# %% [markdown]
# #### 2.3 - Linear regression plots(in seaborn)

# %%
sns.lmplot(data=tips, x='total_bill', y='tip')

# %%
sns.lmplot(data=tips, x='total_bill', y='tip', hue='sex', col='day', row='smoker', height=5, aspect=0.5)

# %%
# Just confirming that "No" smokers on Fri count was infact 4
x = tips[tips['day']=='Fri']
x['smoker'].value_counts()
# Out:
# Yes    15
# No      4
# Name: smoker, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,8))
sns.regplot(data=tips, x='total_bill', y='tip', ax=ax)

# %% [markdown]
# #### 2.4 - Setting some plot aesthetics

# %%
def sinplot():
    x = np.linspace(0,50,100)
    y = np.sin(0.5*x)
    plt.plot(x,y)

sinplot()

# %%
# These are the available params to tweak w.r.t axes
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('ticks', {'axes.grid': True, 'xtick.direction': 'in', 'xtick.color': '.30'})
sinplot()
sns.despine(left=True)

# %%
sns.set_style('darkgrid')
sns.set_context('poster', font_scale=1.2)
sinplot()

# %% [markdown]
# ## 3. plotly and cufflinks
